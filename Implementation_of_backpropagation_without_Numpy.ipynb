# %% [markdown]
# <a href="https://colab.research.google.com/github/siva123h/NNDL/blob/main/Implementation_of_backpropagation_without_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
# Sigmoid function
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# Derivative of sigmoid
def sigmoid_derivative(y):
    return y * (1 - y)

# Training data (XOR)
X = [[0,0], [0,1], [1,0], [1,1]]
Y = [0, 1, 1, 0]

# Initialize weights and biases randomly
w1 = [[random.random(), random.random()],
      [random.random(), random.random()]]
b1 = [0, 0]

w2 = [random.random(), random.random()]
b2 = random.random()

learning_rate = 0.5

# Training
for epoch in range(10000):
    total_error = 0

    for x, y in zip(X, Y):

        # -------- Forward Pass --------
        h = []
        for i in range(2):
            net = x[0]*w1[0][i] + x[1]*w1[1][i] + b1[i]
            h.append(sigmoid(net))

        out_net = h[0]*w2[0] + h[1]*w2[1] + b2
        output = sigmoid(out_net)

        # Error
        error = y - output
        total_error += error**2

        # -------- Backpropagation --------
        d_out = error * sigmoid_derivative(output)

        d_h = []
        for i in range(2):
            d_h.append(d_out * w2[i] * sigmoid_derivative(h[i]))

        # Update weights (hidden → output)
        for i in range(2):
            w2[i] += learning_rate * d_out * h[i]
        b2 += learning_rate * d_out

        # Update weights (input → hidden)
        for i in range(2):
            w1[0][i] += learning_rate * d_h[i] * x[0]
            w1[1][i] += learning_rate * d_h[i] * x[1]
            b1[i] += learning_rate * d_h[i]

    if epoch % 1000 == 0:
        print("Epoch:", epoch, "Error:", total_error)

# -------- Final Output --------
print("\nFinal Predictions:")
for x in X:
    h = []
    for i in range(2):
        net = x[0]*w1[0][i] + x[1]*w1[1][i] + b1[i]
        h.append(sigmoid(net))

    out_net = h[0]*w2[0] + h[1]*w2[1] + b2
    print(x, "->", round(sigmoid(out_net), 3))
# Out:
# Epoch: 0 Error: 1.1011316166943033
# Epoch: 1000 Error: 1.03627252441885
# Epoch: 2000 Error: 0.6981650453756814
# Epoch: 3000 Error: 0.020810327587729063
# Epoch: 4000 Error: 0.007588518088218002
# Epoch: 5000 Error: 0.004521241878439252
# Epoch: 6000 Error: 0.0031917544132904654
# Epoch: 7000 Error: 0.0024561115193272353
# Epoch: 8000 Error: 0.0019912455943982012
# Epoch: 9000 Error: 0.0016717735165941183
#
# Final Predictions:
# [0, 0] -> 0.017
# [0, 1] -> 0.982
# [1, 0] -> 0.982
# [1, 1] -> 0.022
